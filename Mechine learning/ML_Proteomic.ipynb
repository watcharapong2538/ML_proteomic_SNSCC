# %% [markdown]
# # Load Libraries

# %%
pip install numpy pandas matplotlib scikit-learn

# %%
import os
import numpy as np  
import matplotlib.pyplot as mtp  
import pandas as pd

# %% [markdown]
# # Load and Prepare Data

# %%
data=pd.read_csv('/Users/watchara.p/Desktop/Gene_UPDEG_ML.csv',low_memory=False)
data.head()
# Out:
#    Genes  ACE2    ALKBH8    AMOTL1      ANK2    ARID5A     ASB17  ASH2L  \
# 0      0   0.0  8.386579  7.287812  7.731897  7.368372  7.284393    0.0
# 1      0   0.0  0.000000  0.000000  8.511641  0.000000  0.000000    0.0
# 2      0   0.0  0.000000  0.000000  7.600124  0.000000  0.000000    0.0
# 3      0   0.0  0.000000  0.000000  7.779532  0.000000  0.000000    0.0
# 4      0   0.0  0.000000  0.000000  8.534909  0.000000  0.000000    0.0
#
#        ASZ1      ATRX  ...   TWISTNB     UBAC2    UBTFL1  UNC13A      VARS  \
# 0  8.205363  15.73572  ...  6.943974  8.694908  14.47735     0.0  6.958369
# 1  8.778321  15.85638  ...  6.122663  0.000000  14.48805     0.0  0.000000
# 2  8.217196  15.92986  ...  6.036867  0.000000   0.00000     0.0  0.000000
# 3  9.049714   0.00000  ...  6.474401  0.000000   0.00000     0.0  0.000000
# 4  8.489758   0.00000  ...  7.170546  0.000000   0.00000     0.0  0.000000
#
#       WDR34   ZCCHC24     ZFP42    ZNF234    ZNF608
# 0  7.934554  7.278980  15.92713  12.00545  6.813715
# 1  0.000000  7.631227  16.02296  12.18443  6.558315
# 2  0.000000  7.203963   0.00000  12.49294  6.657884
# 3  0.000000  7.756562   0.00000   0.00000  0.000000
# 4  0.000000  7.699783   0.00000   0.00000  0.000000
#
# [5 rows x 172 columns]

# %% [markdown]
# # Assuming the first column is the label and the rest are features
# # x = Features (proteomic data) (cloumn 2-171)
# # y = Labels (SNSCC=1 and NP=0) (first column)

# %%
x=data.iloc[:,1 :171]
y=data.iloc[:,0]

x
y
# Out:
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
#      ..
# 85    1
# 86    1
# 87    1
# 88    1
# 89    1
# Name: Genes, Length: 90, dtype: int64

# %% [markdown]
# # Normalize and scale the data

# %%
from sklearn.preprocessing import StandardScaler ,LabelEncoder


scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)
x_scaled = pd.DataFrame(x_scaled, columns=x.columns)
x_scaled.head()
# Out:
#        ACE2    ALKBH8    AMOTL1      ANK2    ARID5A     ASB17     ASH2L  \
# 0 -0.515201  1.089754  0.710475  0.518007  0.728325  0.594013 -0.372478
# 1 -0.515201 -0.440277 -0.581321  0.641747 -0.520842 -0.583988 -0.372478
# 2 -0.515201 -0.440277 -0.581321  0.497096 -0.520842 -0.583988 -0.372478
# 3 -0.515201 -0.440277 -0.581321  0.525566 -0.520842 -0.583988 -0.372478
# 4 -0.515201 -0.440277 -0.581321  0.645440 -0.520842 -0.583988 -0.372478
#
#        ASZ1      ATRX     BAHD1  ...       TTN   TWISTNB     UBAC2    UBTFL1  \
# 0  1.079314  1.230101  1.184819  ...  0.572354  0.516912  0.980553  2.286427
# 1  1.194179  1.245646  0.937470  ... -0.653418  0.378849 -0.564246  2.288434
# 2  1.081686  1.255113 -0.529142  ... -0.653418  0.364427 -0.564246 -0.428941
# 3  1.248588 -0.797197 -0.529142  ... -0.653418  0.437976 -0.564246 -0.428941
# 4  1.136329 -0.797197 -0.529142  ... -0.653418  0.554999 -0.564246 -0.428941
#
#      UNC13A      VARS     WDR34   ZCCHC24     ZFP42    ZNF234
# 0 -0.266343  0.886951  1.154492  0.570002  1.922749  1.721796
# 1 -0.266343 -0.459615 -0.478538  0.626359  1.937430  1.754370
# 2 -0.266343 -0.459615 -0.478538  0.558000 -0.517245  1.810518
# 3 -0.266343 -0.459615 -0.478538  0.646412 -0.517245 -0.463163
# 4 -0.266343 -0.459615 -0.478538  0.637328 -0.517245 -0.463163
#
# [5 rows x 170 columns]

# %% [markdown]
# # Split data into training and testing sets
# # train_test_split: Splits the data into training (80%) and test_size=0.2 (testing (20%) sets), maintaining the same class distribution in both sets (stratification).
# # stratify make the y have the same proportion between Y train and Y test

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler 
from sklearn.preprocessing import LabelEncoder
from matplotlib import pyplot as plt

X_train, X_test, Y_train, Y_test = train_test_split(x_scaled, y, test_size=0.2, stratify=y, random_state=2)



print ('X_test number', X_test.shape[0])
print ('X_train number', X_train.shape[0])
count1 = np.count_nonzero(Y_train)
count2 = np.count_nonzero(Y_test)
print("Count of SNSCC in Y_train:", count1)
print("Count of SNSCC in Y_test:", count2)
# Out:
# X_test number 18
# X_train number 72
# Count of SNSCC in Y_train: 34
# Count of SNSCC in Y_test: 8

# %% [markdown]
# # Train and Evaluate Models

# %%
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split, cross_val_score, KFold, LeaveOneOut
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_curve, auc, precision_recall_curve, confusion_matrix
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
import time
import statistics

# %% [markdown]
# # Model Training and Evaluation: Each model is trained on the training data and evaluated using cross-validation (n_splits=5) (KFold and LeaveOneOut) and various performance metrics (accuracy, precision, recall, F1-score, AUROC, AUPRC, specificity, and sensitivity).
# # use random_state = 0 for

# %%
algo = [
    [RandomForestClassifier(random_state=0), 'RandomForest'],
    [SVC(kernel='linear', probability=True, random_state=0), 'Support vector machine'],
    [LogisticRegression(random_state=0), 'LogisticRegression'],
    [GradientBoostingClassifier(random_state=0), 'Gradientboost']
]

model_scores = []
result = []
looc = LeaveOneOut()
kf = KFold(n_splits=5)

# %%
for a in algo:
    start_time = time.time()
    algo_name = a[1]
    model = a[0]
    model.fit(X_train, Y_train)

    # Cross-validation scores
    cvkfold = cross_val_score(model, X_train, Y_train, cv=kf)
    cvlooc = cross_val_score(model, X_train, Y_train, cv=looc)

    # Model predictions and evaluation (Performance)
    y_pred = model.predict(X_test)
    ac = accuracy_score(Y_test, y_pred)  # Accuracy score
    r = model.score(X_test, Y_test)
    model_scores.append([r, algo_name])
    precision1 = precision_score(Y_test, y_pred)  # Precision
    recall1 = recall_score(Y_test, y_pred)  # Recall
    f1 = f1_score(Y_test, y_pred)  # F1-Score
    fpr, tp, thresholds = roc_curve(Y_test, model.predict_proba(X_test)[:, 1])
    AUROC = auc(fpr, tp)  # Area Under ROC Curve
    precision, recall, thresholds = precision_recall_curve(Y_test, model.predict_proba(X_test)[:, 1])
    AUPRC = auc(recall, precision)  # Area Under Precision-Recall Curve


    confusion = confusion_matrix(Y_test, y_pred)
    total1 = sum(sum(confusion))
    accuracy1 = (confusion[0, 0] + confusion[1, 1]) / total1  # Accuracy from confusion matrix
    specificity1 = confusion[0, 0] / (confusion[0, 0] + confusion[0, 1])  # Specificity
    sensitivity1 = confusion[1, 1] / (confusion[1, 0] + confusion[1, 1])  # Sensitivity (Recall)
    SD_KF = statistics.stdev(cvkfold)  # Standard deviation of KFold CV scores
    SD_loocv = statistics.stdev(cvlooc)  # Standard deviation of LeaveOneOut CV scores

    # Compile results
    values = [cvkfold.mean(), cvlooc.mean(), ac, r, precision1, recall1, f1, AUROC, AUPRC, specificity1, sensitivity1, SD_KF, SD_loocv]
    result.append(values)

    print(f'Model: {algo_name}, time = {(time.time() - start_time)} sec')
    if a[1] in ['RandomForest','Gradientboost']:
        features = pd.Series(model.feature_importances_,index=x_scaled.columns).sort_values(ascending=False)
        ft=pd.DataFrame(features)
        ft.to_csv('/Users/watchara.p/Desktop/'+a[1]+'_features.csv',index=True)
    elif a[1] == 'LogisticRegression' :
        features = pd.Series(model.coef_[0],index=x_scaled.columns).sort_values(ascending=False)
        ft=pd.DataFrame(features)
        ft.to_csv('/Users/watchara.p/Desktop/'+a[1]+'_features.csv',index=True)
    else :
        support_vectors = model.support_vectors_
        dual_coefficients = model.coef_        
        ft = pd.DataFrame(dual_coefficients.T,index=x_scaled.columns)
        ft2 = ft.sort_values(by=ft.columns[0],ascending=False)
        ft2.to_csv('/Users/watchara.p/Desktop/'+a[1]+'_features.csv',index=True)



print(f'best importance score = {max(model_scores)}')
# Out:
# Model: RandomForest, time = 3.1625452041625977 sec
# Model: Support vector machine, time = 0.20469403266906738 sec
# Model: LogisticRegression, time = 0.18140625953674316 sec
# Model: Gradientboost, time = 5.374811887741089 sec
# best importance score = [1.0, 'RandomForest']

# %%
# Display all results
for i, (model, RandomForest) in enumerate(algo):
    print(f'Results for {RandomForest}:')
    print(f'5-fold CV mean: {result[i][0]}')
    print(f'LOOCV mean: {result[i][1]}')
    print(f'Accuracy: {result[i][2]}')
    print(f'R-squared: {result[i][3]}')
    print(f'Precision: {result[i][4]}')
    print(f'Recall: {result[i][5]}')
    print(f'F1-score: {result[i][6]}')
    print(f'AUROC: {result[i][7]}')
    print(f'AUPRC: {result[i][8]}')
    print(f'Specificity: {result[i][9]}')
    print(f'Sensitivity: {result[i][10]}')
    print(f'SD 5-fold CV: {result[i][11]}')
    print(f'SD LOOCV: {result[i][12]}')
    print('')
# Out:
# Results for RandomForest:
# 5-fold CV mean: 1.0
# LOOCV mean: 0.9722222222222222
# Accuracy: 1.0
# R-squared: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# AUROC: 1.0
# AUPRC: 1.0
# Specificity: 1.0
# Sensitivity: 1.0
# SD 5-fold CV: 0.0
# SD LOOCV: 0.1654887956057706
#
# Results for Support vector machine:
# 5-fold CV mean: 0.9438095238095239
# LOOCV mean: 0.9583333333333334
# Accuracy: 0.9444444444444444
# R-squared: 0.9444444444444444
# Precision: 1.0
# Recall: 0.875
# F1-score: 0.9333333333333333
# AUROC: 1.0
# AUPRC: 1.0
# Specificity: 1.0
# Sensitivity: 0.875
# SD 5-fold CV: 0.059514284952259036
# SD LOOCV: 0.2012286205947824
#
# Results for LogisticRegression:
# 5-fold CV mean: 0.9438095238095239
# LOOCV mean: 0.9444444444444444
# Accuracy: 0.9444444444444444
# R-squared: 0.9444444444444444
# Precision: 1.0
# Recall: 0.875
# F1-score: 0.9333333333333333
# AUROC: 1.0
# AUPRC: 1.0
# Specificity: 1.0
# Sensitivity: 0.875
# SD 5-fold CV: 0.059514284952259036
# SD LOOCV: 0.23066889195376988
#
# Results for Gradientboost:
# 5-fold CV mean: 0.7923809523809523
# LOOCV mean: 0.8611111111111112
# Accuracy: 0.9444444444444444
# R-squared: 0.9444444444444444
# Precision: 1.0
# Recall: 0.875
# F1-score: 0.9333333333333333
# AUROC: 1.0
# AUPRC: 1.0
# Specificity: 1.0
# Sensitivity: 0.875
# SD 5-fold CV: 0.04423704442854702
# SD LOOCV: 0.34825745517658624
